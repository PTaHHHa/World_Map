# %%
import pandas
data_crash = pandas.read_json("events.json")
data_crash
df=data_crash.drop(data_crash.columns[0:6],1)
df
#df2=df.drop(df.columns[9],1)
#df2
# Out:
#           Latitude     Longitude AirportCode  \
# 0       30.319723    -81.514167         CRG
# 1       27.463333    -81.366667         SEF
# 2
# 3
# 4       33.736944    -81.818611         6J6
# ...            ...           ...         ...
# 74424
# 74425
# 74426
# 74427
# 74428         None          None        None
#
#                             AirportName InjurySeverity AircraftDamage  \
# 0       Jacksonville Executive Airport       Fatal(3)    Substantial
# 1             Sebring Regional Airport       Fatal(1)      Destroyed
# 2
# 3
# 4             Edgefield County Airport      Non-Fatal    Substantial
# ...                                 ...            ...            ...
# 74424                                        Fatal(4)      Destroyed
# 74425                                        Fatal(2)      Destroyed
# 74426                                       Non-Fatal    Substantial
# 74427                                        Incident
# ...
